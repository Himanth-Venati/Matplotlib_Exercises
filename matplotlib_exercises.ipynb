# %% [markdown]
# Exercise 1: Read the Total profit of all months and show it using a line plot.
# Total profit data provided for each month. The enerated line plot must include the following properties:
#
# X label name = Month Number
# Y label name = Total profit
# The line plot graph should look like this:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('C:/Users/Venati Himanth/OneDrive/Desktop/strive/python/Day8/Matplotlib/exl/company_sales_data.csv')
print(df)

plt.plot(df['month_number'],df['total_profit'])
plt.xlabel('Month number')
plt.ylabel('Total profit')
plt.title('Company profit per month')
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %% [markdown]
# Exercise 2: Get the Total profit of all months and show a line plot with the following Style properties:
# Line Style dotted and Line color should be red
# Show legend at the lower right location.
# X label name = Month Number
# Y label name = Sold units number
# Add a circle marker.
# Line marker color as read
# Line width should be 3
# The line plot graph should look like this:

# %%
plt.plot(df['month_number'],df['total_profit'],'r-',linewidth=3,marker='o',linestyle='dashed',markerfacecolor='Black')
plt.xlabel('Month Number')
plt.ylabel('profit')
plt.title('Company sales data of last year')
plt.legend('Total_profit',loc='lower right',fontsize=7)
# Out:
# C:\Users\VENATI~1\AppData\Local\Temp/ipykernel_6256/1599422900.py:1: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "r-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(df['month_number'],df['total_profit'],'r-',linewidth=3,marker='o',linestyle='dashed',markerfacecolor='Black')

# %% [markdown]
# Exercise 3: Read all product sales data and show it using a multiline plot.
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).
#
# The graph should look like this:

# %%
plt.plot(df['month_number'],df['facecream'],label='facecream data',color='blue',marker='o')
plt.plot(df['month_number'],df['facewash'],label='facewash data',color='orange',marker='o')
plt.plot(df['month_number'],df['toothpaste'],label='toothpaste data',color='green',marker='o')
plt.plot(df['month_number'],df['bathingsoap'],label='bathingsoap data',color='red',marker='o')
plt.plot(df['month_number'],df['shampoo'],label='shampoo data',color='purple',marker='o')
plt.plot(df['month_number'],df['moisturizer'],label='moisturizer data',color='brown',marker='o')

plt.xlabel('Month Number')
plt.ylabel('sales units in number')
plt.title('sales Data')
plt.legend(loc='upper left',fontsize=7)

# %% [markdown]
# Exercise 4: Read the toothpaste sales data of each month and show it using a scatter plot.
# Also, add a grid in the plot (the grid line style should be “–“).
#
# The scatter plot should look like this:

# %%
import seaborn as sns
sns.scatterplot(df['month_number'],df['toothpaste'])
plt.grid(True,linestyle='--',linewidth=1)
plt.xlabel('Month Number')
plt.ylabel('Number of units sold')
plt.title('Toothpaste Sales Data')
# Out:
# C:\Anaconda\envs\strive\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Toothpaste Sales Data')

# %% [markdown]
#  Exercise 5: Read the face cream and facewash product sales data and show it using the bar chart.
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this:

# %%
df3=pd.DataFrame(df,columns=["month_number","facecream ","facewash"])
df.plot(x="month_number",y=["facecream", "facewash"], kind="bar",figsize=(9,8))
plt.grid(linestyle='--',linewidth=2)
plt.xlabel('Month Number')
plt.ylabel('sales units in number')
plt.title('Facewash and Facecream Sales Data')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# Exercise 6: Read the sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk.

# %%
df3=pd.DataFrame(df,columns=["month_number","bathingsoap "])
df.plot(x="month_number",y=["bathingsoap"], kind="bar",figsize=(9,8))
plt.grid(linestyle='--',linewidth=2)
plt.xlabel('Month Number')
plt.ylabel('sales units in number')
plt.title('Bathing Soap Sales Data')
plt.legend()
plt.show()
